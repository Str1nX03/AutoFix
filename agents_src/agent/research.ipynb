# %%
import sys
import os
import uuid

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from agents_src.agent.support_agent import SupportAgent

print("Initializing Support Agent...")
agent = SupportAgent()

session_id = str(uuid.uuid4())

print("Support Agent Ready! Type 'exit' or 'quit' to stop.")
print("-" * 50)

while True:
    user_input = input("You: ")
    
    if user_input.lower() in ['exit', 'quit']:
        print("\nEnding conversation. Goodbye!")
        break
        
    if not user_input.strip():
        continue
        
    try:
        result = agent.run(query=user_input, session_id=session_id)
        
        response = result.get("support_response", "Sorry, I didn't get a response.")
        print(f"\nYou: {user_input}\n")
        print(f"\nAgent: {response}\n")
        print("====" * 20)
        
    except Exception as e:
        print(f"\nError occurred: {e}\n")
# Out:
# Initializing Support Agent...
# Support Agent Ready! Type 'exit' or 'quit' to stop.
# --------------------------------------------------
#
# You: how are you?
#
#
# Agent: Hello! I’m doing great—thanks for asking. How can I help you today? If you’re looking for Razer gear or have any questions about our catalog, just let me know!
#
# ================================================================================
#
# You: what products do you have?
#
#
# Agent: We carry a full range of Razer gaming gear and accessories. Our catalog is organized into the following categories:
#
# - **Mice**
# - **Keyboards**
# - **Headsets & Audio** (Speakers, Subwoofers)
# - **Microphones & Cameras**
# - **Laptops**
# - **Gaming Chairs**
# - **Controllers** (Xbox, PC, Mobile)
# - **Earbuds**
#
# All of our products are from the Razer brand, so you can be confident you’re getting the quality and performance that Razer is known for. If you’re looking for something specific—like a gaming mouse for FPS titles or a headset with 7.1 surround sound—just let me know, and I can help you find the exact Razer item that fits your needs.
#
# ================================================================================
#
# You: can you give me some recommendations on mouses?
#
#
# Agent: Sure thing! Based on our current catalog, we have two great Razer gaming mice that I can recommend for you:
#
# | Product | Key Features | Pros | Cons | Price |
# |---------|--------------|------|------|-------|
# | **Razer DeathAdder V3 Pro** | • 30 K optical sensor<br>• 90 million‑click optical switches<br>• 63 g ultra‑lightweight<br>• Ergonomic right‑handed palm grip | • Extremely lightweight<br>• Excellent sensor performance<br>• Comfortable ergonomic shape | • No RGB lighting<br>• Designed only for right‑handed users | **$149.99** |
# | **Razer Viper V2 Pro** | • 30 K Focus Pro sensor<br>• Gen‑3 optical switches<br>• 58 g ultra‑lightweight<br>• Ambidextrous shape<br>• Up to 80 h battery life | • Flawless wireless tracking<br>• Ambidextrous shape (great for left‑handed users)<br>• Very low weight | • No side grips out of the box<br>• No RGB lighting | **$149.99** |
#
# ### Quick recommendation guide
#
# | Use case | Best pick | Why |
# |----------|-----------|-----|
# | **FPS or competitive shooters** | **Razer DeathAdder V3 Pro** | Its ergonomic palm‑grip shape and lightweight design make it ideal for quick, precise movements. |
# | **All‑round gaming or esports** | **Razer Viper V2 Pro** | Its ambidextrous shape and ultra‑lightweight feel are great for both right‑ and left‑handed players, plus the long battery life keeps you playing longer. |
# | **Left‑handed player** | **Razer Viper V2 Pro** | The ambidextrous design is a clear advantage for left‑handed users. |
# | **Right‑handed player who wants a classic feel** | **Razer DeathAdder V3 Pro** | The DeathAdder shape is a proven favorite for right‑handed gamers. |
#
# Both mice are priced the same at **$149.99**, so your choice will mainly come down to grip preference and whether you need an ambidextrous design.
#
# Let me know if you’d like more details on either model, or if you have a specific game or playstyle in mind—I can help narrow it down even further!
#
# ================================================================================
#
# You: do you have any other mouses?
#
#
# Agent: Absolutely! In addition to the **DeathAdder V3 Pro** and **Viper V2 Pro** we’ve already discussed, we also carry the **Razer Basilisk V3 Pro**.
#
# **Razer Basilisk V3 Pro**
# - **Wireless, fully customizable** with 11 programmable buttons
# - **Hyperscroll tilt wheel** for smooth, infinite scrolling
# - **13‑zone Chroma RGB underglow** for a stunning look
# - **30 K optical sensor** for precise tracking
# - **Price:** $159.99
#
# If you’d like more details—such as battery life, ergonomics, or how it compares to the other Razer mice—just let me know!
#
# ================================================================================
#
# You: which is the cheapest mouse you have?
#
#
# Agent: Both the **Razer DeathAdder V3 Pro** and the **Razer Viper V2 Pro** are priced at **$149.99**, which is the lowest price for a mouse in our catalog. The **Razer Basilisk V3 Pro** is a bit higher at **$159.99**. So if you’re looking for the most budget‑friendly option, either the DeathAdder or the Viper would be the best picks.
#
# ================================================================================
#
# You: what about keyboards?
#
#
# Agent: Sure thing! Here are the Razer keyboards we currently have in stock:
#
# | Product | Key Features | Pros | Cons | Price |
# |---------|--------------|------|------|-------|
# | **Razer Huntsman V2** | • Full‑size optical gaming keyboard<br>• Razer Linear Optical Switches (near‑zero latency)<br>• Sound‑dampening foam<br>• Double‑shot PBT keycaps<br>• Plush leatherette wrist rest | • Zero‑latency optical switches<br>• Comfortable wrist rest<br>• Durable PBT keycaps | • Linear switches can be noisy<br>• Cable is not detachable | **$199.99** |
# | **Razer BlackWidow V4 Pro** | • Premium mechanical keyboard<br>• Green tactile switches<br>• Dedicated command dial<br>• 8 dedicated macro keys<br>• Magnetic plush wrist rest<br>• 3‑side Chroma underglow | • Dedicated macro keys & command dial<br>• Bright RGB underglow<br>• Premium build quality | • Takes up a lot of desk space<br>• Expensive for a wired keyboard | **$229.99** |
#
# ### Quick pick‑guide
#
# | Use case | Best pick | Why |
# |----------|-----------|-----|
# | **Fast, low‑latency gaming** | **Razer Huntsman V2** | Optical switches give near‑zero latency, great for competitive play. |
# | **Heavy macro usage / customization** | **Razer BlackWidow V4 Pro** | 8 macro keys + command dial let you set up complex commands easily. |
# | **RGB lighting & visual flair** | **Razer BlackWidow V4 Pro** | 3‑side Chroma underglow is more immersive than the Huntsman’s single‑zone lighting. |
# | **Desk space is a concern** | **Razer Huntsman V2** | Slightly slimmer profile and lighter weight. |
#
# Let me know if you’d like more details on either keyboard, or if you have a specific use‑case (e.g., esports, streaming, office work) so I can fine‑tune the recommendation for you!
#
# ================================================================================
#
# Ending conversation. Goodbye!
